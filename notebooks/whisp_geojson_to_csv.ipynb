# %% [markdown]
# ## Process a GeoJSON

# %% [markdown]
# Python Notebook pathway for [Whisp](https://openforis.org/solutions/whisp/) for running locally.
#
# - Use this notebook for datasets up to around 100,000 features. For larger datasets consider the 'whisp_ee_asset_to_drive.ipynb' notebook.
# - Please log any issues/requests [here](https://github.com/forestdatapartnership/whisp/issues)
#
# Setup
# - Use a [virtual environment](https://docs.python.org/3/tutorial/venv.html) to avoid altering your python environment
#
# **To run:** click play buttons (or press shift + enter)
#
# **Requirements:** Google Earth Engine (GEE) account and registered cloud project.
#
# - **Aim:** support compliance with zero deforestation regulations
# - **Input**: geojson file of plot boundaries or points
# - **Output**: CSV table and geojson containing statistics and risk indicators

# %%
# =============================================================================
# Google Earth Engine initialization for WHISP
# Project: whisp-503523
# =============================================================================

import ee
from pathlib import Path
import datetime

PROJECT_ID = "whisp-503523"

# Reset any previous Earth Engine session
ee.Reset()

try:
    # Try using existing credentials
    ee.Initialize(
        project=PROJECT_ID,
        opt_url="https://earthengine-highvolume.googleapis.com"
    )
    print("Earth Engine initialized successfully.")

except Exception:
    print("Authentication required...")
    ee.Authenticate()

    ee.Initialize(
        project=PROJECT_ID,
        opt_url="https://earthengine-highvolume.googleapis.com"
    )

    print("Earth Engine authenticated and initialized successfully.")
# Out:
# Earth Engine initialized successfully.

# %%
# Install openforis-whisp (uncomment line if not already installed)
# !pip install --pre openforis-whisp

# NB for editable mode install via your terminal with: pip install -e .[dev]

# %%
import openforis_whisp as whisp

# %%
import openforis_whisp
print(openforis_whisp.__file__)
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\openforis_whisp\__init__.py

# %% [markdown]
# Get a GeoJSON (choose Option A or B below)

# %%
# Project paths
PROJECT_DIR = Path.cwd().parent
INPUT_DIR = PROJECT_DIR / "data" / "input"
OUTPUT_DIR = PROJECT_DIR / "data" / "outputs"

GEOJSON_PATH = INPUT_DIR / "Testing_santander.geojson"

print(GEOJSON_PATH)
# Out:
# d:\00_Portafolio\WHISP\data\input\Testing_santander.geojson

# %%
## Option B: Fetch from asset registry (uncomment to use) — https://data.apps.fao.org/geospatial/v2/api/catalog/features
# from openforis_whisp.asset_registry import fetch_and_save
# GEOJSON_PATH = fetch_and_save(catalog_id="asif_test", collection_id="col_polygons")

# %%
import geopandas as gpd
gdf = gpd.read_file(GEOJSON_PATH)
gdf.plot(figsize=(6,6))
# Out:
# <Axes: >

# %% [markdown]
# Prepare layers

# %%
# Choose if want to include additional custom layers
USE_CUSTOM_BANDS = False # set to True if want to add extra ee data to whisp

# %%
# =============================================================================
# CUSTOM BANDS SETUP (OPTIONAL) - runs only if USE_CUSTOM_BANDS = True above
# =============================================================================
if USE_CUSTOM_BANDS:

    # Step 1: Define custom Earth Engine images (binary values 0 or 1). Currently showing example placeholders.
    custom_images = {
        'example_treecover': ee.Image(1),  # ee.Image("UMD/hansen/global_forest_change_2024_v1_12").select("treecover2000").gt(10).selfMask()
        'nXX_example_commodity': ee.Image(1) # ee.ImageCollection("projects/forestdatapartnership/assets/cocoa/model_2025a").filter(ee.Filter.date('2020-01-01', '2021-01-01')).mosaic().gt(.8).selfMask()
        # add more images as needed (prefix 'nXX_' = iso2 code for national dataset)
    }

    # Step 2: Define metadata for each custom band (keys must match above)
    # Themes: 'treecover', 'commodities', 'disturbance_before', 'disturbance_after'
    # Timber themes: 'primary', 'naturally_reg_2020', 'planted_plantation_2020', etc.
    custom_bands_info = {
        'example_treecover': {
            'ISO2_code': "",          # Country code (empty = all countries)
            'theme': 'treecover',     # Risk theme
            'theme_timber': "",       # Timber theme (if applicable)
            'use_for_risk_pcrop': 1,  # Include in perennial crop risk (1=yes, 0=no)        # Include in risk calculations (1=yes, 0=no)
            'use_for_risk_acrop': 1,   # Include in annual crop risk (1=yes, 0=no)
            'use_for_risk_timber': 0  # Include in timber risk (1=yes, 0=no)
        },
        'nXX_example_commodity': {
            'ISO2_code': "XX", 
            'theme': 'commodities', 
            'theme_timber': "",
            'use_for_risk_pcrop': 1,  # Include in perennial crop risk (1=yes, 0=no) 
            'use_for_risk_acrop': 1,   # Include in annual crop risk (1=yes, 0=no)
            'use_for_risk_timber': 0
        }
        # add more band metadata as needed
    }

    # Step 3: Combine custom bands and extract names
    custom_ee_image = whisp.combine_custom_bands(custom_images, custom_bands_info)

    custom_bands = list(custom_bands_info.keys())

# %%
print(whisp)
# Out:
# <module 'openforis_whisp' from 'c:\\Users\\ASUS\\anaconda3\\Lib\\site-packages\\openforis_whisp\\__init__.py'>

# %%
print(iso2_codes_list)
# Out:
# ['co', 'ci', 'br', 'cm']

# %%
# Create final Whisp image
whisp_image = whisp.combine_datasets(national_codes=iso2_codes_list, auto_recovery=True)
standard_bands = len(whisp_image.bandNames().getInfo())

if USE_CUSTOM_BANDS and 'custom_ee_image' in locals():
    whisp_image = whisp_image.addBands(custom_ee_image)
    print(f"Final image has {standard_bands + len(custom_bands)} bands ({standard_bands} + {len(custom_bands)} custom)")
else:
    print(f"Final image has {standard_bands} bands")
# Out:
# Whisp multiband image compiled
# Final image has 231 bands

# %%
# Choose additional national datasets to include (currently four countries: 'co', 'ci', 'br', 'cm').
base_iso2_codes = ['co', 'ci', 'br', 'cm']

# automatically add any custom ISO2 codes from custom_bands_info if USE_CUSTOM_BANDS is True
iso2_codes_list = base_iso2_codes.copy()
if USE_CUSTOM_BANDS:
    iso2_codes_list += [code.lower() for code in {v.get('ISO2_code') for v in custom_bands_info.values()} if code and code.lower() not in iso2_codes_list]

# %%
#Preguntando que capas de COLOMBIA ^^!
bandas = whisp_image.bandNames().getInfo()
for b in bandas:
    if b.startswith('nCO_'):
        print(b)

# Si por alguna razón quiero ver cada una, solo debo revisar el código fuente, debería estar en datasets.py
# Out:
# nCO_ideam_eufo_commission_2020
# nCO_ideam_forest_2020

# %% [markdown]
# Run stats processing

# %%
print(GEOJSON_PATH)
# Out:
# d:\00_Portafolio\WHISP\data\input\Testing_santander.geojson

# %%
df_stats = whisp.whisp_formatted_stats_geojson_to_df(
    input_geojson_filepath=GEOJSON_PATH,
    # external_id_column="user_id",  # optional - specify which input column/property to map to the external ID.
    national_codes=iso2_codes_list,  # optional - By default national datasets are not included unless specified here.
    # unit_type='percent',  # optional - to change unit type. Default is 'ha'.
    whisp_image=whisp_image,  # optional - defaults to standard whisp image if not provided
    custom_bands=custom_bands if USE_CUSTOM_BANDS else None,  # include custom bands in formatted output
    mode = "concurrent" # batch processing mode most useful for large datasets 
)
# Out:
# INFO: Mode: concurrent
# INFO: Loaded 1 features
# INFO: Processing 1 features in 1 batches (concurrent mode)...
# ERROR: Batch 0 failed: Batch 1: User memory limit exceeded.
# INFO: Processing complete: 0/1 batches in 2.5m
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df_stats = whisp.whisp_formatted_stats_geojson_to_df(
#       2     input_geojson_filepath=GEOJSON_PATH,
#       3     # external_id_column="user_id",  # optional - specify which input column/property to map to the external ID.
#       4     national_codes=iso2_codes_list,  # optional - By default national datasets are not included unless specified here.
#       5     # unit_type='percent',  # optional - to change unit type. Default is 'ha'.
#       6     whisp_image=whisp_image,  # optional - defaults to standard whisp image if not provided
#       7     custom_bands=custom_bands if USE_CUSTOM_BANDS else None,  # include custom bands in formatted output
#       8     mode = "concurrent" # batch processing mode most useful for large datasets
#       9 )
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\openforis_whisp\stats.py:314, in whisp_formatted_stats_geojson_to_df(input_geojson_filepath, external_id_column, remove_geom, national_codes, unit_type, whisp_image, custom_bands, mode, batch_size, max_concurrent, geometry_audit_trail, output_dir)
#     309             logger.info(
#     310                 f"Mode is 'sequential': {', '.join(unused)}\n"
#     311                 "parameter(s) are not used in sequential (single-threaded) mode."
#     312             )
#     313     # Route to fast function with explicit mode (skip auto-detection)
# --> 314     return whisp_formatted_stats_geojson_to_df_fast(
#     315         input_geojson_filepath=input_geojson_filepath,
#     316         external_id_column=external_id_column,
#     317         national_codes=national_codes,
#     318         unit_type=unit_type,
#     319         whisp_image=whisp_image,
#     320         custom_bands=custom_bands,
#     321         mode=mode,  # Pass mode directly (concurrent or sequential)
#     322         batch_size=batch_size,
#     323         max_concurrent=max_concurrent,
#     324         geometry_audit_trail=geometry_audit_trail,
#     325     )
#     326 elif mode == "local":
#     327     # Import local_stats module
#     328     from openforis_whisp.local_stats import whisp_stats_local
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\openforis_whisp\advanced_stats.py:2451, in whisp_formatted_stats_geojson_to_df_fast(input_geojson_filepath, external_id_column, national_codes, unit_type, whisp_image, custom_bands, mode, batch_size, max_concurrent, validate_geometries, max_retries, add_metadata_server, decimal_places, remove_median_columns, convert_water_flag, water_flag_threshold, sort_column, geometry_audit_trail)
#    2449 if mode == "concurrent":
#    2450     logger.debug("Routing to concurrent processing...")
# -> 2451     return whisp_formatted_stats_geojson_to_df_concurrent(
#    2452         input_geojson_filepath=input_geojson_filepath,
#    2453         external_id_column=external_id_column,
#    2454         national_codes=national_codes,
#    2455         unit_type=unit_type,
#    2456         whisp_image=whisp_image,
#    2457         custom_bands=custom_bands,
#    2458         batch_size=batch_size,
#    2459         max_concurrent=max_concurrent,
#    2460         validate_geometries=validate_geometries,
#    2461         max_retries=max_retries,
#    2462         add_metadata_server=add_metadata_server,
#    2463         logger=logger,
#    2464         decimal_places=decimal_places,
#    2465         remove_median_columns=remove_median_columns,
#    2466         convert_water_flag=convert_water_flag,
#    2467         water_flag_threshold=water_flag_threshold,
#    2468         sort_column=sort_column,
#    2469         geometry_audit_trail=geometry_audit_trail,
#    2470     )
#    2471 else:  # sequential
#    2472     logger.debug("Routing to sequential processing...")
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\openforis_whisp\advanced_stats.py:2094, in whisp_formatted_stats_geojson_to_df_concurrent(input_geojson_filepath, external_id_column, national_codes, unit_type, whisp_image, custom_bands, batch_size, max_concurrent, validate_geometries, max_retries, add_metadata_server, logger, decimal_places, remove_median_columns, convert_water_flag, water_flag_threshold, sort_column, geometry_audit_trail)
#    2092 # Step 1: Get raw stats
#    2093 logger.debug("Step 1/2: Extracting statistics (concurrent)...")
# -> 2094 df_raw = whisp_stats_geojson_to_df_concurrent(
#    2095     input_geojson_filepath=input_geojson_filepath,
#    2096     external_id_column=external_id_column,
#    2097     national_codes=national_codes,
#    2098     unit_type=unit_type,
#    2099     whisp_image=whisp_image,
#    2100     custom_bands=custom_bands,
#    2101     batch_size=batch_size,
#    2102     max_concurrent=max_concurrent,
#    2103     validate_geometries=validate_geometries,
#    2104     max_retries=max_retries,
#    2105     add_metadata_server=add_metadata_server,
#    2106     logger=logger,
#    2107 )
#    2109 # Step 2: Format the output
#    2110 logger.debug("Step 2/2: Formatting output...")
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\openforis_whisp\advanced_stats.py:1479, in whisp_stats_geojson_to_df_concurrent(input_geojson_filepath, external_id_column, national_codes, unit_type, whisp_image, custom_bands, batch_size, max_concurrent, validate_geometries, max_retries, add_metadata_server, logger, decimal_places)
#    1471         suggestions.append(
#    1472             "  • Processing timeout: reduce batch_size or simplify input geometries"
#    1473         )
#    1475     suggestions_text = (
#    1476         "\nDebugging hints:\n" + "\n".join(suggestions) if suggestions else ""
#    1477     )
# -> 1479     raise RuntimeError(
#    1480         f"Failed to process {len(batch_errors)} batch(es):\n"
#    1481         f"\n{error_details}\n"
#    1482         f"\nTotal rows affected: {total_failed_rows}\n"
#    1483         f"{suggestions_text}\n"
#    1484         f"Please reduce batch_size and try again."
#    1485     )
#    1487 # Check we have results
#    1488 if not results:
#
# RuntimeError: Failed to process 1 batch(es):
#
#   Batch 0 (1 features): Batch 1: User memory limit exceeded.
#
# Total rows affected: 1
#
# Debugging hints:
#   • Reduce batch_size parameter (currently: 10). Try: batch_size=5 or lower
# Please reduce batch_size and try again.

# %% [markdown]
# Display results

# %%
df_stats

# %% [markdown]
# Calculate risk category

# %%
# adds risk columns to end of dataframe
df_w_risk = whisp.whisp_risk(
    df=df_stats,
    national_codes=iso2_codes_list,
    custom_bands_info=custom_bands_info if USE_CUSTOM_BANDS else None,  # Add: missing custom bands
    # drop_unused_columns=True # set to True to remove stats columns not used for risk  
)

# %% [markdown]
# Display table with risk columns

# %%
df_w_risk

# %% [markdown]
# Export table to CSV

# %%
# Generate timestamp 
timestamp = datetime.datetime.now().strftime("%Y_%m_%d_%H_%M")

# Add a suffix to indicate notebook pathway (e.g., '_nb' for notebook)
output_filename = f"whisp_analysis_{timestamp}_nb.csv"

# Define the output folder
project_dir = Path.cwd().parent
out_directory = project_dir / "data" / "outputs" / "csv"
csv_output_file = out_directory / output_filename

# Save the CSV file
df_w_risk.to_csv(path_or_buf=csv_output_file, index=False)
print(f"Table with risk columns saved to: {csv_output_file}")

# %% [markdown]
# Export to GeoJSON (optional)

# %%
# Define the output file path for GeoJSON
output_filename = f"whisp_analysis_{timestamp}_nb.geojson"
geojson_output_file = project_dir / "data" / "outputs" / "geojson" / output_filename

# Save the GeoJSON file
whisp.convert_df_to_geojson(df_w_risk, geojson_output_file)  # builds a geojson file containing Whisp columns. Uses the geometry column "geo" to create the spatial features.

print(f"GeoJSON saved to: {geojson_output_file}")
